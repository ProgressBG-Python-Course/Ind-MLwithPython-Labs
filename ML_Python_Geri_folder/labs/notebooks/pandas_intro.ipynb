# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6]],index=['a','b'],columns=['col1','col2','col3'])
df
# Out:
#    col1  col2  col3
# a     1     2     3
# b     4     5     6

# %%
data_0 = pd.read_excel('D:/NanoReg2/NanoReg/ENPRA/P04_ParisDiderot/Ready Cell viability PI/ENPRA-WP4-P4-Ag-NM300-NCIH-292-Cell_ViabilityCytotox-PI.xls',sheet_name=0)
data_0.head(10)
# Out:
#    RAW DATA   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0       NaN          NaN        NaN        NaN        NaN         NaN
# 1       NaN          NaN        NaN        NaN        NaN         NaN
# 2       NaN  Replicate 1        NaN        NaN        NaN         NaN
# 3       NaN           H1      Test1      Test2      Test3         NaN
# 4       NaN            0        6.9       4.31       4.49         NaN
# 5       NaN          7.5      70.91      95.03      84.53         NaN
# 6       NaN           15      94.76       96.2      92.82         NaN
# 7       NaN           30      96.49      96.93      94.93         NaN
# 8       NaN           60      97.61      97.05      97.54         NaN
# 9       NaN            0        NaN        NaN        NaN         NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0          NaN        NaN        NaN        NaN          NaN          NaN
# ...

# %%
data_1 = pd.read_excel('D:/NanoReg2/NanoReg/ENPRA/P04_ParisDiderot/Ready Cell viability PI/ENPRA-WP4-P4-Ag-NM300-NCIH-292-Cell_ViabilityCytotox-PI.xls',sheet_name=1)
data_1.head(10)
# Out:
#    RAW DATA   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0       NaN          NaN        NaN        NaN        NaN         NaN
# 1       NaN          NaN        NaN        NaN        NaN         NaN
# 2       NaN  Replicate 1        NaN        NaN        NaN         NaN
# 3       NaN           H1      Test1      Test2      Test3         NaN
# 4       NaN            0        6.9       4.31       4.49         NaN
# 5       NaN          7.5      70.91      95.03      84.53         NaN
# 6       NaN           15      94.76       96.2      92.82         NaN
# 7       NaN           30      96.49      96.93      94.93         NaN
# 8       NaN           60      97.61      97.05      97.54         NaN
# 9       NaN            0        NaN        NaN        NaN         NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0          NaN        NaN        NaN        NaN          NaN          NaN
# ...

# %%
data_2 = pd.read_excel('D:/NanoReg2/NanoReg/ENPRA/P04_ParisDiderot/Ready Cell viability PI/ENPRA-WP4-P4-Ag-NM300-NCIH-292-Cell_ViabilityCytotox-PI.xls',sheet_name=2)
data_2.head(10)
# Out:
#    TEST RESULTS   Unnamed: 1 Unnamed: 2        Unnamed: 3  \
# 0           NaN          NaN        NaN               NaN
# 1           NaN          NaN        NaN               NaN
# 2           NaN  Replicate 1        NaN               NaN
# 3           NaN           H1         Ag  Average raw data
# 4           NaN          NaN          0           5.23333
# 5           NaN          NaN        7.5             83.49
# 6           NaN          NaN         15           94.5933
# 7           NaN          NaN         30           96.1167
# 8           NaN          NaN         60              97.4
# 9           NaN          NaN          0               NaN
#
#                       Unnamed: 4  Unnamed: 5   Unnamed: 6 Unnamed: 7  \
# 0                            NaN         NaN          NaN        NaN
# 1                            NaN         NaN          NaN        NaN
# 2                            NaN         NaN  Replicate 2        NaN
# ...
