# %% [markdown]
# ## homework for lab6 $ lab7

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("D:/ML_Pyton_course/ML_Python/labs/datasets/housing.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
index = data.index
print(index)
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
data.shape
# Out:
# (506, 14)

# %%
#data.info
print(data.describe())
print(data.head())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# max for crim
max_crim = data.crim.max()
print(max_crim)
# min for crim
min_crim = data.crim.min()
print(min_crim)
# Out:
# 88.9762
# 0.00632

# %%
# max crim for tax
data.loc[data.crim == max_crim,'tax']
# Out:
# 380    666
# Name: tax, dtype: int64

# %%
data_drinks = pd.read_csv("D:/ML_Pyton_course/ML_Python/labs/datasets/various/drinks.csv")
data_drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# which country has a max beer servise
max_beer=data_drinks.beer_servings.max()
print(max_beer)
data_drinks.loc[data_drinks.beer_servings==max_beer,'country']
# Out:
# 376
# 117    Namibia
# Name: country, dtype: object

# %%
# which country has a max spirit servise in continent
max_spirit = data_drinks.spirit_servings.max()
print(max_spirit)
data_drinks.loc[data_drinks.spirit_servings == max_spirit,'continent']
# Out:
# 438
# 68    NaN
# Name: continent, dtype: object

# %%
mean_wine_servings = data_drinks.wine_servings.mean()
data_drinks[ (data_drinks.wine_servings > mean_wine_servings) & (data_drinks.continent != 'SA')]
# Out:
#                  country  beer_servings  spirit_servings  wine_servings  \
# 1                Albania             89              132             54
# 3                Andorra            245              138            312
# 8              Australia            261               72            212
# 9                Austria            279               75            191
# 11               Bahamas            122              176             51
# 16               Belgium            295               84            212
# 25              Bulgaria            231              252             94
# 32                Canada            240              122            100
# 40          Cook Islands              0              254             74
# 42               Croatia            230               87            254
# 44                Cyprus            192              154            113
# 45        Czech Republic            361              170            134
# ...

# %%
data_drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000
